# %%
import numpy as np
import pandas as pd

# %%
data2 = pd.read_csv('/Users/sdbgpro/Documents/THP/data/S2/mardi/data_cleaning/data/db_start/openaq.csv', sep=';')

data2
# Out:
#       Country Code               City  \
# 0               DK         Syddanmark
# 1               DK        Hovedstaden
# 2               HU           Veszprém
# 3               HU  Gyor-Moson-Sopron
# 4               MX         GUANAJUATO
# ...            ...                ...
# 41631           GB           Haringey
# 41632           GB  Brighton and Hove
# 41633           GB        Westminster
# 41634           GB        Westminster
# 41635           GB            Crawley
#
#                                        Location  \
# 0                                       DK0031A
# 1                                       DK0034A
# 2                                       HU0037A
# 3                                       HU0035A
# 4                            Estación Nativitas
# ...                                         ...
# 41631             Haringey  - Priory Park South
# 41632          Brighton and Hove - Preston Park
# 41633  Westminster - Waterloo Pl (Crown Estate)
# ...
